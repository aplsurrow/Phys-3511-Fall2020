# %% [markdown]
# # Pandas (documentation reference in *Help* tab)
#
# * Open source library build on numpy library
# * Allows for data analysis, cleaning, and preperation
# * Provides built in visual features
# * Many data formats can be used with it
# * Alot like a suped up excel

# %% [markdown]
# ## Installing Pandas
#
# * To install pandas under anaconda:
# > conda install pandas
# * To insall pandas from python
# > pip install pandas

# %% [markdown]
# ## Series
# Simple to import pandas into Jupyter Notebook

# %%
#series are similar to numpy arrays and are built on array object

# They differ from numpy arrays because they allow indexing by labels (like a dictionary)

import numpy as np
import pandas as pd

# %%
# 4 python objects
labels = ['a','b','c'] # list of strings
my_data = [10,20,30] # list of ints
array = np.array(my_data) # numpy array
d = {'a':10, 'b':20, 'c':30} # dictionary

# %%
# show object type
print(type(labels))
print(type(my_data))
print(type(array))
print(type(d))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'dict'>

# %% [markdown]
# We can use a series using by calling Series() from our pandas object

# %%
# Use shit+tab to show important input values of data and index
#explain index and data columns
pd.Series(data=my_data, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#no index provided, defaults to ints
pd.Series(my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
#data = and index = not needed if you keep correct order
pd.Series(my_data,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(labels,my_data)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
pd.Series(index=labels,data=my_data)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#series can hold many kinds of objects
#here data are strings
pd.Series(labels,my_data)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#refs to other objects
pd.Series([print,len])
# Out:
# 0    <built-in function print>
# 1      <built-in function len>
# dtype: object

# %%
#Getting info from a series works on indexing
ser1 = pd.Series(my_data,labels)
ser1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1['a']
# Out:
# 10

# %%
#Getting info from a series works on indexing
ser1 = pd.Series(labels)
ser1
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser1[1]
# Out:
# 'b'

# %%
ser1 = pd.Series([1,2,3],['a','b','c'])
ser2 = pd.Series([1,3,4],['a','b','d'])

print(ser1)
print(ser2)
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# b    3
# d    4
# dtype: int64

# %%
#basic operations are based on indexing
# pandas can't find a matching index data value is set to NaN
# pands converts automatically numbers to floats
ser1 + ser2
# Out:
# a    2.0
# b    5.0
# c    NaN
# d    NaN
# dtype: float64

# %% [markdown]
# # DataFrames
#
# ## A DataFrame is a set of pandas Series that share a common index
# Create a DataFrame object by calling
# >pandas.DataFrame(data,index,column)

# %%
# main pandas tool
# show 'shit+tab' of function note input: data, index, columns
# data, index just like series
np.random.seed(101)
df = pd.DataFrame(np.random.randn(5,4),['a','b','c','d','e'],['w','x','y','z'])
df
#Each column (w,x,y,z) is a pandas series that shares a common index (a,b,c,d,e)
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
#can also use python print, but loose some visual features
print(df)

#getting info out
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
#get column
# this is the same as a pandas Series
df['w']
# Out:
# a    2.706850
# b    0.651118
# c   -2.018168
# d    0.188695
# e    0.190794
# Name: w, dtype: float64

# %%
type(df['w'])
# Out:
# pandas.core.series.Series

# %%
#df is type DataFrame
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#How to get list of methods for DataFrame --> df. (tab)

#How to get multiple columns, more than 1 series from the DataFrame --> use a list
df[['w','z']]
# Out:
#           w         z
# a  2.706850  0.503826
# b  0.651118  0.605965
# c -2.018168 -0.589001
# d  0.188695  0.955057
# e  0.190794  0.683509

# %% [markdown]
# #in jupyter notebook Series and DataFrame can be distinguished by visual output difference

# %% [markdown]
# Creating new columns in a DataFrame

# %%
df['new']
#KeyError mean no Key 'new' was found
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-d388a5380aa6> in <module>
# ----> 1 df['new']
#       2 #KeyError mean no Key 'new' was found
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new'

# %%
df['new'] = df['x'] + df['y']

# %%
df

# %% [markdown]
# To Remove columns use the method
# > drop()

# %%
#Get error KeyError: not found in axis
#by default drop() uses axis = 0, which is for rows.
#axis = 1 is for columns. Ala numpy
#show using 'shift+tab' after drop
df.drop('new')

# %%
df.drop('new',axis=1)

# %%
#show df, why is new back?
#With drop method by default does not modify the DataFrame object so you don't accidently loose info
#to switch modification on or off we need to switch inPlace to True or False
#show 'tab+shift' drop method again
df

# %%
df.drop('new',axis=1,inplace=True)

# %%
df

# %%
# to drop a row
#both equivelant (i.e. axis = 0 by default)
df.drop('e', axis=0)
#df.drop('e')

# %%
#above not done inplace, so DataFrame still has row
df

# %%
df.shape
#(rows, columns) just like numpy array

# %% [markdown]
# Access rows using:
# > loc[label index ]
#
# > iloc[numerical index]

# %%
#rows are also a pandas Series
df.loc['c']

# %%
df.iloc[2]

# %%
#Getting info works just like numpy refferencing
df.loc['b','y']

# %%
df.loc['b']['y']

# %%
df.loc[ ['a','b'],['w','y'] ]

# %%
df.iloc[0:2,:]

# %%
df.iloc[0:2,2:]

# %% [markdown]
# Conditional Selections

# %%
df

# %%
# where is DataFrame > 0
#returns boolean values
df > 0

# %%
booldf = df > 0

# %%
booldf

# %%
# values = true
# Nan = false
df[booldf]

# %%
#could do same thing
df[df > 0]

# %%
#typically you want to check a row or column and not the entire DataFrame
df['w'] >0

# %%
df['w']

# %%
#Can filter rows based on True/False of a row
#below returns only row where w >0
#when you pass Series values you do not get nan, only when you pass the entire DataFrame
df[ df['w'] > 0]

# %%
#conditional return DataFrame, we can call methods off the returned DataFrame
result_df = df[df['w'] > 0] 
result_df

# %%
#reutrn x column of result_df
result_df['x']

# %%
# one step
#retun rows where W > 0 is true and return the x column of those values
df[ df['w'] > 0 ]['x']

# %%
df[ df['w'] > 0 ][['x','y']]

# %%
#find rows where w colum is > 0
boolser = df['w'] > 0
print('boolser:\n')
print(boolser)

#Return DataFrame where boolser is true
resultser = df[boolser]
print('resultser:\n')
print(resultser)

#get list of x,y columns 
print('my_cols:\n')
my_cols = ['x','y']
print(my_cols)

#list x,y columns for rows where the w > 0 column was true
finalser = resultser[my_cols]
print('finalser:\n')
print(finalser)

# %%
finalser

# %%
#Why is one line better than multiple?
#each variable you define takes up memory

# %%
#mulitple conditions

df[df['w'] > 0 and df['y'] > 1]

# %%
# ambiguous error is because we are using 'and' to compare a series of booleans to a series of booleans
#python 'and' and only compare 1 boolean value to another
True and False

df['w'] > 0

# %%
#each condition in ( )
df[ (df['w'] > 0) & (df['y'] > 1) ]

# %%
df[ (df['w'] > 0) | (df['y'] > 1) ]

# %%
#modifyiing the index
df

# %%
df.reset_index()

# %%
#does not happen in place
df
#need to use
#df.reset_index(inplace=True)

# %%
#add new index to our DataFrame

#cool trick
newind = 'electron tau proton neutron pion'.split()
newind

# %%
# add to DataFrame
df['particles'] = newind

# %%
df

# %%
#how do we make particles our index?
df.set_index('particles')

# %%
#not inplace
df

# %%
df.set_index('particles',inplace=True)

# %%
df

# %%
df

# %% [markdown]
# ## Missing Data
#
# pandas can account for missing data via NAN

# %%
d = {'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]}
df = pd.DataFrame(d)
df

# %% [markdown]
# The dropna method

# %%
#drops any row with NaN (one or more)
df.dropna()

# %%
# to drop columns look at 'tab+shift', dropna take axis argument
#axis = 1, drops columns with NaN
df.dropna(axis=1)

# %%
#threshold says how many NaN's are needed before it drops it
print(df)
df.dropna(thresh=2)

# %%
#How can we fill NaN?
df.fillna('Fill Value')

# %%
df['A']

# %%
#fill with the mean of the column
#what to fill with depends on what you are doing
df['A'].fillna(value = df['A'].mean())

# %% [markdown]
# ## Groupby
#
# * Allows you to group together rows based off a column and then perform aggergate functions on them.
# * Aggergate function takes many values and returns one value (e.g. mean, sum, std, ...)
#
# ![groupby.png](attachment:groupby.png)

# %%
data = {'Type':['Boson','Hadron','Boson','Boson','Fermions','Hadron'],
        'Particle':['gluon','proton','W','Z','electron','neutron'],
        'Mass (GeV)':[0.0,0.938,80.385,91.19,5.11e-3,0.939]}

# %%
df = pd.DataFrame(data)
df
# Out:
#        Type  Particle  Mass (GeV)
# 0     Boson     gluon     0.00000
# 1    Hadron    proton     0.93800
# 2     Boson         W    80.38500
# 3     Boson         Z    91.19000
# 4  Fermions  electron     0.00511
# 5    Hadron   neutron     0.93900

# %%
#group rows together by type
df.groupby('Type')
#gives a groupby object where it is stored in memory

# %%
#groupby object
bytype = df.groupby('Type')

# %%
#mean mass for each particle type
#can't perform mean on strings, i.e no particle mean, so its ignored
bytype.mean()
# Out:
#           Mass (GeV)
# Type
# Boson      57.191667
# Fermions    0.005110
# Hadron      0.938500

# %%
bytype.sum()
# Out:
#           Mass (GeV)
# Type
# Boson      171.57500
# Fermions     0.00511
# Hadron       1.87700

# %%
bytype.std()
# Out:
#           Mass (GeV)
# Type
# Boson      49.823208
# Fermions         NaN
# Hadron      0.000707

# %%
#returns a DataFrame

#Sum of all Bosons
bytype.sum().loc['Boson']
# Out:
# Mass (GeV)    171.575
# Name: Boson, dtype: float64

# %%
#in one line
df.groupby('Type').sum().loc['Boson']
# Out:
# Mass (GeV)    171.575
# Name: Boson, dtype: float64

# %%
df.groupby('Type').count()
# Out:
#           Particle  Mass (GeV)
# Type
# Boson            3           3
# Fermions         1           1
# Hadron           2           2

# %%
#string are location in alphabet
df.groupby('Type').max()
# Out:
#           Particle  Mass (GeV)
# Type
# Boson        gluon    91.19000
# Fermions  electron     0.00511
# Hadron      proton     0.93900

# %%
df.groupby('Type').min()
# Out:
#           Particle  Mass (GeV)
# Type
# Boson            W     0.00000
# Fermions  electron     0.00511
# Hadron     neutron     0.93800

# %%
df.groupby('Type').describe()
# Out:
#          Mass (GeV)                                                     \
#               count       mean        std      min       25%       50%
# Type
# Boson           3.0  57.191667  49.823208  0.00000  40.19250  80.38500
# Fermions        1.0   0.005110        NaN  0.00511   0.00511   0.00511
# Hadron          2.0   0.938500   0.000707  0.93800   0.93825   0.93850
#
#
#                75%       max
# Type
# Boson     85.78750  91.19000
# Fermions   0.00511   0.00511
# Hadron     0.93875   0.93900

# %%
df.groupby('Type').describe().transpose()
# Out:
# Type                  Boson  Fermions    Hadron
# Mass (GeV) count   3.000000   1.00000  2.000000
#            mean   57.191667   0.00511  0.938500
#            std    49.823208       NaN  0.000707
#            min     0.000000   0.00511  0.938000
#            25%    40.192500   0.00511  0.938250
#            50%    80.385000   0.00511  0.938500
#            75%    85.787500   0.00511  0.938750
#            max    91.190000   0.00511  0.939000

# %% [markdown]
# ## Operations

# %%
df1 = pd.DataFrame({'A':[1,2,3],
                    'B':[10,20,10],
                    'C':['C0','C1','C2']})

df1.head()
# Out:
#    A   B   C
# 0  1  10  C0
# 1  2  20  C1
# 2  3  10  C2

# %%
#unique value method
df1['B'].unique()
# Out:
# array([10, 20])

# %%
# to get number of unique numbers
len(df1['B'].unique())
# Out:
# 2

# %%
df1['B'].nunique()
# Out:
# 2

# %%
#value count
df1['B'].value_counts()
# Out:
# 10    2
# 20    1
# Name: B, dtype: int64

# %%
df1[df1['B']>10]
# Out:
#    A   B   C
# 1  2  20  C1

# %% [markdown]
# Apply Method

# %%
def times2(x):
    return x*2

# %%
#we can use many built in methods e.g. sum, mean ...
df1['B'].sum()

#but what about our own?
#Broadcasrs function to column in DataFrame
df1['B'].apply(times2)
# Out:
# 0    20
# 1    40
# 2    20
# Name: B, dtype: int64

# %%
#Can use other defined functions.
df1['C'].apply(len)
# Out:
# 0    2
# 1    2
# 2    2
# Name: C, dtype: int64

# %%
#do this with lambda expression
df1['B'].apply(lambda x: x*2)
# Out:
# 0    20
# 1    40
# 2    20
# Name: B, dtype: int64

# %%
df1
# Out:
#    A   B   C
# 0  1  10  C0
# 1  2  20  C1
# 2  3  10  C2

# %% [markdown]
# Removing columns

# %%
#need inplace = True to keep changes
df1.drop('C',axis=1)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  10

# %%
df1
# Out:
#    A   B   C
# 0  1  10  C0
# 1  2  20  C1
# 2  3  10  C2

# %%
#return list of column names
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# ## Sorting and Ordering

# %%
#sort by Column B
df1.sort_values('B')
#index stays with row.
# Out:
#    A   B   C
# 0  1  10  C0
# 2  3  10  C2
# 1  2  20  C1

# %% [markdown]
# Finding nulls in data set

# %%
#reutens boolean of True/False
df1.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False

# %% [markdown]
# # Data Indput and Output

# %%
pwd
# Out:
# '/Users/aplsurrrow/Desktop/Temple University/Phys-3511-Fall2020-master/Module05'

# %%
df = pd.read_csv('data/Wmunu_Run2011A.csv')

# %%
df.head()
df.tail()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155599 entries, 0 to 155598
# Data columns (total 9 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   pt      155599 non-null  float64
#  1   eta     155599 non-null  float64
#  2   phi     155599 non-null  float64
#  3   Q       155599 non-null  int64
#  4   chiSq   155599 non-null  float64
#  5   dxy     155599 non-null  float64
#  6   iso     155599 non-null  float64
#  7   MET     155599 non-null  float64
#  8   phiMET  155599 non-null  float64
# dtypes: float64(8), int64(1)
# memory usage: 10.7 MB

# %%
#this will save index as a column
#df.to_csv('My_output')
df.to_csv('My_output', index = False)

# %%
df = pd.read_csv('My_output')
df.head()
# Out:
#       Run      Event       pt       eta       phi  Q       chiSq       dxy  \
# 0  173389  489963747  29.3153 -0.139250  1.356110  1    0.845578 -0.060012
# 1  173389  490024840  44.1461 -1.359000 -0.538965  1    1.294310 -0.012581
# 2  173389  490102189  42.7895 -1.019350  2.339020 -1    0.807800 -0.084001
# 3  173389  490092121  31.2215 -0.127033 -0.488923 -1  109.949000  0.072264
# 4  173389  490193981  36.9668  1.855660  1.377200  1    1.059700 -0.067624
#
#         iso       MET    phiMET
# 0   0.00000  30.66700 -2.130810
# 1  26.34230  27.95210 -2.668610
# 2   2.97476   5.15651  0.306059
# 3  56.48970   4.21427 -0.116569
# 4  41.49100  20.99630 -1.625060

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# DataFrame has built in visualizations built on Matplotlib

# %%
df.hist('eta',bins = 100);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Can also reference columns using '.'

# %%
print(df.eta,df.pt)
# Out:
# 0        -0.139250
# 1        -1.359000
# 2        -1.019350
# 3        -0.127033
# 4         1.855660
#             ...
# 155594   -0.999186
# 155595   -1.184380
# 155596    0.970982
# 155597   -0.733396
# 155598    0.694119
# Name: eta, Length: 155599, dtype: float64 0         29.3153
# 1         44.1461
# 2         42.7895
# 3         31.2215
# 4         36.9668
#            ...
# 155594    32.9560
# 155595    31.2633
# 155596    35.8388
# 155597    36.1021
# 155598    38.0196
# Name: pt, Length: 155599, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.hist(df.eta,bins =100);
ax.set_xlim(-2,2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-2.0, 2.0)

# %%
df.corr()
# Out:
#              Run     Event        pt       eta       phi         Q     chiSq  \
# Run     1.000000  0.390749  0.004954 -0.002072 -0.001864  0.008508  0.001904
# Event   0.390749  1.000000  0.001338 -0.000211  0.003056  0.004658 -0.000009
# pt      0.004954  0.001338  1.000000 -0.003668 -0.002401 -0.003488  0.000478
# eta    -0.002072 -0.000211 -0.003668  1.000000  0.001232  0.005068  0.001761
# phi    -0.001864  0.003056 -0.002401  0.001232  1.000000  0.000495 -0.001147
# Q       0.008508  0.004658 -0.003488  0.005068  0.000495  1.000000 -0.002851
# chiSq   0.001904 -0.000009  0.000478  0.001761 -0.001147 -0.002851  1.000000
# dxy     0.000336 -0.004619  0.000318  0.000291 -0.015958 -0.000899 -0.000342
# iso    -0.013162 -0.002975  0.009147 -0.001654  0.000545 -0.014848  0.002059
# MET     0.053144  0.014585  0.008152 -0.004462  0.019467  0.042271 -0.000426
# phiMET -0.000821 -0.003343  0.000362  0.000196 -0.159403 -0.004179  0.003225
#
#              dxy       iso       MET    phiMET
# Run     0.000336 -0.013162  0.053144 -0.000821
# Event  -0.004619 -0.002975  0.014585 -0.003343
# pt      0.000318  0.009147  0.008152  0.000362
# eta     0.000291 -0.001654 -0.004462  0.000196
# phi    -0.015958  0.000545  0.019467 -0.159403
# Q      -0.000899 -0.014848  0.042271 -0.004179
# chiSq  -0.000342  0.002059 -0.000426  0.003225
# dxy     1.000000  0.000696  0.003061  0.003424
# iso     0.000696  1.000000 -0.075675 -0.002840
# MET     0.003061 -0.075675  1.000000 -0.013193
# phiMET  0.003424 -0.002840 -0.013193  1.000000

# %%
df.drop(['Run','Event'],axis=1,inplace=True)

# %%
df
# Out:
#              pt       eta       phi  Q       chiSq       dxy        iso  \
# 0       29.3153 -0.139250  1.356110  1    0.845578 -0.060012   0.000000
# 1       44.1461 -1.359000 -0.538965  1    1.294310 -0.012581  26.342300
# 2       42.7895 -1.019350  2.339020 -1    0.807800 -0.084001   2.974760
# 3       31.2215 -0.127033 -0.488923 -1  109.949000  0.072264  56.489700
# 4       36.9668  1.855660  1.377200  1    1.059700 -0.067624  41.491000
# ...         ...       ...       ... ..         ...       ...        ...
# 155594  32.9560 -0.999186  2.730180 -1    1.002640 -0.063018   0.000000
# 155595  31.2633 -1.184380  1.245790  1    1.015220 -0.063928   0.941652
# 155596  35.8388  0.970982  1.562630 -1    1.461930 -0.077680  36.223900
# 155597  36.1021 -0.733396 -2.923620 -1    1.271120 -0.027985   1.235320
# 155598  38.0196  0.694119  1.485260 -1    0.785298 -0.073642   8.618690
#
#              MET    phiMET
# 0       30.66700 -2.130810
# 1       27.95210 -2.668610
# 2        5.15651  0.306059
# 3        4.21427 -0.116569
# 4       20.99630 -1.625060
# ...          ...       ...
# 155594  33.12890 -0.075555
# 155595  24.03410 -2.679180
# 155596  12.78920  1.471490
# 155597  42.77720 -0.097858
# 155598  27.73310 -2.688870
#
# [155599 rows x 9 columns]

# %%
corr_matrix = df.corr()
print(corr_matrix)
# Out:
#               pt       eta       phi         Q     chiSq       dxy       iso  \
# pt      1.000000 -0.003668 -0.002401 -0.003488  0.000478  0.000318  0.009147
# eta    -0.003668  1.000000  0.001232  0.005068  0.001761  0.000291 -0.001654
# phi    -0.002401  0.001232  1.000000  0.000495 -0.001147 -0.015958  0.000545
# Q      -0.003488  0.005068  0.000495  1.000000 -0.002851 -0.000899 -0.014848
# chiSq   0.000478  0.001761 -0.001147 -0.002851  1.000000 -0.000342  0.002059
# dxy     0.000318  0.000291 -0.015958 -0.000899 -0.000342  1.000000  0.000696
# iso     0.009147 -0.001654  0.000545 -0.014848  0.002059  0.000696  1.000000
# MET     0.008152 -0.004462  0.019467  0.042271 -0.000426  0.003061 -0.075675
# phiMET  0.000362  0.000196 -0.159403 -0.004179  0.003225  0.003424 -0.002840
#
#              MET    phiMET
# pt      0.008152  0.000362
# eta    -0.004462  0.000196
# phi     0.019467 -0.159403
# Q       0.042271 -0.004179
# chiSq  -0.000426  0.003225
# dxy     0.003061  0.003424
# iso    -0.075675 -0.002840
# MET     1.000000 -0.013193
# phiMET -0.013193  1.000000

# %%
fig = plt.figure()
plt.imshow(corr_matrix)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = df.copy()
df2.drop(['Q','chiSq','dxy','iso','phiMET'],axis=1,inplace=True)

# %%
df2.head()
# Out:
#         pt       eta       phi       MET
# 0  29.3153 -0.139250  1.356110  30.66700
# 1  44.1461 -1.359000 -0.538965  27.95210
# 2  42.7895 -1.019350  2.339020   5.15651
# 3  31.2215 -0.127033 -0.488923   4.21427
# 4  36.9668  1.855660  1.377200  20.99630

# %%
df2.corr()
# Out:
#            pt       eta       phi       MET
# pt   1.000000 -0.003668 -0.002401  0.008152
# eta -0.003668  1.000000  0.001232 -0.004462
# phi -0.002401  0.001232  1.000000  0.019467
# MET  0.008152 -0.004462  0.019467  1.000000

# %%
fig = plt.figure()
plt.imshow(df2.corr())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import seaborn as sns

# %%
fig = plt.figure()
sns.heatmap(df2.corr(),annot=True)
plt.title('Seaborn');
# Out:
# <img src="data:image/png;base64,..." width="640">
